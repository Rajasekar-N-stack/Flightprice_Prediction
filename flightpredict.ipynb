# %%
# Importing the Necessary Libraries for Prediction.
# Download the Train Data and Test Data files.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('Train.csv')
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR ? DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU ? IXR ? BBI ? BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL ? LKO ? BOM ? COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU ? NAG ? BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR ? NAG ? DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU ? BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU ? BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR ? DEL    08:20         11:20       3h    non-stop
# 10681              BLR ? DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL ? GOI ? BOM ? COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR ? DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL ? LKO ? BOM ? COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU ? NAG ? BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR ? NAG ? DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.tail()
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time Arrival_Time Duration Total_Stops  \
# 10678              CCU ? BLR    19:55        22:25   2h 30m    non-stop
# 10679              CCU ? BLR    20:45        23:20   2h 35m    non-stop
# 10680              BLR ? DEL    08:20        11:20       3h    non-stop
# 10681              BLR ? DEL    11:30        14:10   2h 40m    non-stop
# 10682  DEL ? GOI ? BOM ? COK    10:55        19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
df.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df.sample(5)
# Out:
#           Airline Date_of_Journey   Source Destination            Route  \
# 8066        GoAir       6/05/2019  Kolkata    Banglore  CCU ? AMD ? BLR
# 1053       IndiGo      27/06/2019    Delhi      Cochin  DEL ? HYD ? COK
# 3775  Jet Airways      12/05/2019  Kolkata    Banglore  CCU ? BOM ? BLR
# 1001     SpiceJet      15/05/2019  Chennai     Kolkata        MAA ? CCU
# 9852      Vistara      12/03/2019   Mumbai   Hyderabad  BOM ? DEL ? HYD
#
#      Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info  \
# 8066    16:40  00:15 07 May   7h 35m      1 stop                      No info
# 1053    07:35         12:10   4h 35m      1 stop                      No info
# 3775    06:30  09:20 13 May  26h 50m      1 stop  In-flight meal not included
# 1001    09:45         12:00   2h 15m    non-stop                      No info
# 9852    19:45  19:55 13 Mar  24h 10m      1 stop                      No info
#
#       Price
# 8066   7102
# 1053   5054
# 3775   9663
# 1001   3597
# 9852  12080

# %%
df['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
df.sample(10)
# Out:
#           Airline Date_of_Journey    Source Destination  \
# 1312  Jet Airways       9/06/2019     Delhi      Cochin
# 4063  Jet Airways       9/06/2019     Delhi      Cochin
# 2709       IndiGo      15/05/2019   Kolkata    Banglore
# 9261  Jet Airways      15/06/2019     Delhi      Cochin
# 1121       IndiGo       6/03/2019     Delhi      Cochin
# 7     Jet Airways      01/03/2019  Banglore   New Delhi
# 5604       IndiGo       9/03/2019     Delhi      Cochin
# 9292      Vistara       1/04/2019   Kolkata    Banglore
# 7873  Jet Airways      15/05/2019   Kolkata    Banglore
# 4920  Jet Airways      21/05/2019     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 1312  DEL ? NAG ? BOM ? COK    06:45  12:35 10 Jun  29h 50m     2 stops
# 4063        DEL ? BOM ? COK    19:15  12:35 10 Jun  17h 20m      1 stop
# 2709              CCU ? BLR    14:25         16:55   2h 30m    non-stop
# 9261  DEL ? NAG ? BOM ? COK    14:35  12:35 16 Jun      22h     2 stops
# 1121        DEL ? BOM ? COK    09:10  01:35 07 Mar  16h 25m      1 stop
# 7           BLR ? BOM ? DEL    08:00  05:05 02 Mar   21h 5m      1 stop
# 5604        DEL ? HYD ? COK    06:40         16:10   9h 30m      1 stop
# 9292        CCU ? DEL ? BLR    20:20  20:20 02 Apr      24h      1 stop
# 7873        CCU ? BOM ? BLR    06:30         18:15  11h 45m      1 stop
# 4920  DEL ? JAI ? BOM ? COK    05:30  04:25 22 May  22h 55m     2 stops
#
#                   Additional_Info  Price
# 1312                      No info  13376
# 4063  In-flight meal not included  10577
# 2709                      No info   5224
# 9261  In-flight meal not included  10919
# 1121                      No info  14871
# 7                         No info  22270
# 5604                      No info   6442
# 9292                      No info   8452
# 7873  In-flight meal not included  10844
# 4920                      No info  15129

# %%
df[df['Airline'] == 'IndiGo']
# Out:
#       Airline Date_of_Journey    Source Destination            Route Dep_Time  \
# 0      IndiGo      24/03/2019  Banglore   New Delhi        BLR ? DEL    22:20
# 3      IndiGo      12/05/2019   Kolkata    Banglore  CCU ? NAG ? BLR    18:05
# 4      IndiGo      01/03/2019  Banglore   New Delhi  BLR ? NAG ? DEL    16:50
# 11     IndiGo      18/04/2019   Kolkata    Banglore        CCU ? BLR    20:20
# 14     IndiGo      24/04/2019   Kolkata    Banglore        CCU ? BLR    17:15
# ...       ...             ...       ...         ...              ...      ...
# 10631  IndiGo      15/05/2019     Delhi      Cochin  DEL ? BLR ? COK    02:00
# 10641  IndiGo       6/03/2019   Chennai     Kolkata        MAA ? CCU    07:55
# 10649  IndiGo       1/03/2019   Kolkata    Banglore        CCU ? BLR    21:25
# 10664  IndiGo       9/04/2019  Banglore       Delhi        BLR ? DEL    18:55
# 10665  IndiGo      27/04/2019   Kolkata    Banglore        CCU ? BLR    15:15
#
#        Arrival_Time Duration Total_Stops Additional_Info  Price
# 0      01:10 22 Mar   2h 50m    non-stop         No info   3897
# 3             23:30   5h 25m      1 stop         No info   6218
# 4             21:35   4h 45m      1 stop         No info  13302
# 11            22:55   2h 35m    non-stop         No info   4174
# 14            19:50   2h 35m    non-stop         No info   4804
# ...             ...      ...         ...             ...    ...
# 10631         07:45   5h 45m      1 stop         No info   6037
# 10641         10:15   2h 20m    non-stop         No info   7295
# 10649  00:05 02 Mar   2h 40m    non-stop         No info   4778
# 10664         21:50   2h 55m    non-stop         No info   4823
# 10665         17:45   2h 30m    non-stop         No info   4804
#
# [2053 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
df['Dep_Time'].value_counts()
# Out:
# Dep_Time
# 18:55    233
# 17:00    227
# 07:05    205
# 10:00    203
# 07:10    202
#         ...
# 16:25      1
# 01:35      1
# 21:35      1
# 04:15      1
# 03:00      1
# Name: count, Length: 222, dtype: int64

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df.Additional_Info.nunique()
# Out:
# 10

# %%
df.Additional_Info.value_counts()
# Out:
# Additional_Info
# No info                         8345
# In-flight meal not included     1982
# No check-in baggage included     320
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# No Info                            3
# 1 Short layover                    1
# Red-eye flight                     1
# 2 Long layover                     1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR ? DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL ? LKO ? BOM ? COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU ? NAG ? BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR ? NAG ? DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302
