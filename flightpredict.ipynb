# %%
# Importing the Necessary Libraries for Prediction.
# Download the Train Data and Test Data files.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('Train.csv')
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR ? DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU ? IXR ? BBI ? BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR ? DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL ? LKO ? BOM ? COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU ? NAG ? BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR ? NAG ? DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.tail()
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time Arrival_Time Duration Total_Stops  \
# 10678              CCU ? BLR    19:55        22:25   2h 30m    non-stop
# 10679              CCU ? BLR    20:45        23:20   2h 35m    non-stop
# 10680              BLR ? DEL    08:20        11:20       3h    non-stop
# 10681              BLR ? DEL    11:30        14:10   2h 40m    non-stop
# 10682  DEL ? GOI ? BOM ? COK    10:55        19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
df.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %%
df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df.sample(5)
# Out:
#                 Airline Date_of_Journey   Source Destination            Route  \
# 5022        Jet Airways       1/05/2019  Kolkata    Banglore  CCU ? DEL ? BLR
# 408   Multiple carriers       3/06/2019    Delhi      Cochin  DEL ? BOM ? COK
# 7313        Jet Airways       1/05/2019  Kolkata    Banglore  CCU ? BOM ? BLR
# 1274            Vistara      27/03/2019  Chennai     Kolkata        MAA ? CCU
# 6068        Jet Airways       9/05/2019  Kolkata    Banglore  CCU ? BOM ? BLR
#
#      Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info  \
# 5022    20:25  18:00 02 May  21h 35m      1 stop  In-flight meal not included
# 408     13:00         19:15   6h 15m      1 stop                      No info
# 7313    14:05         19:50   5h 45m      1 stop                      No info
# 1274    07:05         09:20   2h 15m    non-stop                      No info
# 6068    14:05         19:50   5h 45m      1 stop  In-flight meal not included
#
#       Price
# 5022   9314
# ...

# %%
df['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
df.sample(10)
# Out:
#                  Airline Date_of_Journey    Source Destination  \
# 10295           Air Asia      18/04/2019   Kolkata    Banglore
# 2110   Multiple carriers      21/03/2019     Delhi      Cochin
# 1958            Air Asia      15/05/2019  Banglore       Delhi
# 10305           SpiceJet      18/03/2019   Chennai     Kolkata
# 2013         Jet Airways      21/03/2019     Delhi      Cochin
# 6763         Jet Airways       6/06/2019   Kolkata    Banglore
# 3331           Air India       6/03/2019    Mumbai   Hyderabad
# 4875           Air India      24/03/2019   Kolkata    Banglore
# 5832            SpiceJet      18/05/2019   Chennai     Kolkata
# 8725   Multiple carriers       3/06/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 10295              CCU ? BLR    19:55         22:25   2h 30m    non-stop
# 2110         DEL ? BOM ? COK    08:00         21:00      13h      1 stop
# ...

# %%
df[df['Airline'] == 'IndiGo']
# Out:
#       Airline Date_of_Journey    Source Destination            Route Dep_Time  \
# 0      IndiGo      24/03/2019  Banglore   New Delhi        BLR ? DEL    22:20
# 3      IndiGo      12/05/2019   Kolkata    Banglore  CCU ? NAG ? BLR    18:05
# 4      IndiGo      01/03/2019  Banglore   New Delhi  BLR ? NAG ? DEL    16:50
# 11     IndiGo      18/04/2019   Kolkata    Banglore        CCU ? BLR    20:20
# 14     IndiGo      24/04/2019   Kolkata    Banglore        CCU ? BLR    17:15
# ...       ...             ...       ...         ...              ...      ...
# 10631  IndiGo      15/05/2019     Delhi      Cochin  DEL ? BLR ? COK    02:00
# 10641  IndiGo       6/03/2019   Chennai     Kolkata        MAA ? CCU    07:55
# 10649  IndiGo       1/03/2019   Kolkata    Banglore        CCU ? BLR    21:25
# 10664  IndiGo       9/04/2019  Banglore       Delhi        BLR ? DEL    18:55
# 10665  IndiGo      27/04/2019   Kolkata    Banglore        CCU ? BLR    15:15
#
# ...

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
df['Dep_Time'].value_counts()
# Out:
# Dep_Time
# 18:55    233
# 17:00    227
# 07:05    205
# 10:00    203
# 07:10    202
#         ...
# 16:25      1
# 01:35      1
# 21:35      1
# 04:15      1
# 03:00      1
# Name: count, Length: 222, dtype: int64

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df.Additional_Info.nunique()
# Out:
# 10

# %%
df.Additional_Info.value_counts()
# Out:
# Additional_Info
# No info                         8345
# In-flight meal not included     1982
# No check-in baggage included     320
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# No Info                            3
# 1 Short layover                    1
# Red-eye flight                     1
# 2 Long layover                     1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR ? DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL ? LKO ? BOM ? COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU ? NAG ? BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR ? NAG ? DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.rename(columns={"Date_of_Journey" : 'DateofJourney'},inplace=True)
df
# Out:
#            Airline DateofJourney    Source Destination                  Route  \
# 0           IndiGo    24/03/2019  Banglore   New Delhi              BLR ? DEL
# 1        Air India     1/05/2019   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2      Jet Airways     9/06/2019     Delhi      Cochin  DEL ? LKO ? BOM ? COK
# 3           IndiGo    12/05/2019   Kolkata    Banglore        CCU ? NAG ? BLR
# 4           IndiGo    01/03/2019  Banglore   New Delhi        BLR ? NAG ? DEL
# ...            ...           ...       ...         ...                    ...
# 10678     Air Asia     9/04/2019   Kolkata    Banglore              CCU ? BLR
# 10679    Air India    27/04/2019   Kolkata    Banglore              CCU ? BLR
# 10680  Jet Airways    27/04/2019  Banglore       Delhi              BLR ? DEL
# 10681      Vistara    01/03/2019  Banglore   New Delhi              BLR ? DEL
# 10682    Air India     9/05/2019     Delhi      Cochin  DEL ? GOI ? BOM ? COK
#
# ...

# %%
df.rename(columns={"Dep_Time" : "DepTime","Arrival_Time" : 'ArrivalTime',"Total_Stops":"Totalstops","Additional_Info":'AdditionalInfo'},inplace=True)
df
# Out:
#            Airline DateofJourney    Source Destination                  Route  \
# 0           IndiGo    24/03/2019  Banglore   New Delhi              BLR ? DEL
# 1        Air India     1/05/2019   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2      Jet Airways     9/06/2019     Delhi      Cochin  DEL ? LKO ? BOM ? COK
# 3           IndiGo    12/05/2019   Kolkata    Banglore        CCU ? NAG ? BLR
# 4           IndiGo    01/03/2019  Banglore   New Delhi        BLR ? NAG ? DEL
# ...            ...           ...       ...         ...                    ...
# 10678     Air Asia     9/04/2019   Kolkata    Banglore              CCU ? BLR
# 10679    Air India    27/04/2019   Kolkata    Banglore              CCU ? BLR
# 10680  Jet Airways    27/04/2019  Banglore       Delhi              BLR ? DEL
# 10681      Vistara    01/03/2019  Banglore   New Delhi              BLR ? DEL
# 10682    Air India     9/05/2019     Delhi      Cochin  DEL ? GOI ? BOM ? COK
#
# ...

# %%
df.isna().any()
# Out:
# Airline           False
# DateofJourney     False
# Source            False
# Destination       False
# Route              True
# DepTime           False
# ArrivalTime       False
# Duration          False
# Totalstops         True
# AdditionalInfo    False
# Price             False
# dtype: bool

# %%
df.drop(columns='Route',inplace=True)

# %%
df1 = pd.read_csv('Test.csv')
df1
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0           Jet Airways       6/06/2019     Delhi      Cochin
# 1                IndiGo      12/05/2019   Kolkata    Banglore
# 2           Jet Airways      21/05/2019     Delhi      Cochin
# 3     Multiple carriers      21/05/2019     Delhi      Cochin
# 4              Air Asia      24/06/2019  Banglore       Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                 Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0     DEL ? BOM ? COK    17:30  04:25 07 Jun  10h 55m      1 stop
# 1     CCU ? MAA ? BLR    06:20         10:20       4h      1 stop
# ...

# %%
df
# Out:
#            Airline DateofJourney    Source Destination                  Route  \
# 0           IndiGo    24/03/2019  Banglore   New Delhi              BLR ? DEL
# 1        Air India     1/05/2019   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2      Jet Airways     9/06/2019     Delhi      Cochin  DEL ? LKO ? BOM ? COK
# 3           IndiGo    12/05/2019   Kolkata    Banglore        CCU ? NAG ? BLR
# 4           IndiGo    01/03/2019  Banglore   New Delhi        BLR ? NAG ? DEL
# ...            ...           ...       ...         ...                    ...
# 10678     Air Asia     9/04/2019   Kolkata    Banglore              CCU ? BLR
# 10679    Air India    27/04/2019   Kolkata    Banglore              CCU ? BLR
# 10680  Jet Airways    27/04/2019  Banglore       Delhi              BLR ? DEL
# 10681      Vistara    01/03/2019  Banglore   New Delhi              BLR ? DEL
# 10682    Air India     9/05/2019     Delhi      Cochin  DEL ? GOI ? BOM ? COK
#
# ...

# %%
df
# Out:
#            Airline DateofJourney    Source Destination                  Route  \
# 0           IndiGo    24/03/2019  Banglore   New Delhi              BLR ? DEL
# 1        Air India     1/05/2019   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2      Jet Airways     9/06/2019     Delhi      Cochin  DEL ? LKO ? BOM ? COK
# 3           IndiGo    12/05/2019   Kolkata    Banglore        CCU ? NAG ? BLR
# 4           IndiGo    01/03/2019  Banglore   New Delhi        BLR ? NAG ? DEL
# ...            ...           ...       ...         ...                    ...
# 10678     Air Asia     9/04/2019   Kolkata    Banglore              CCU ? BLR
# 10679    Air India    27/04/2019   Kolkata    Banglore              CCU ? BLR
# 10680  Jet Airways    27/04/2019  Banglore       Delhi              BLR ? DEL
# 10681      Vistara    01/03/2019  Banglore   New Delhi              BLR ? DEL
# 10682    Air India     9/05/2019     Delhi      Cochin  DEL ? GOI ? BOM ? COK
#
# ...

# %%
df1.rename(columns={"Dep_Time" : "DepTime","Arrival_Time" : 'ArrivalTime',"Total_Stops":"Totalstops","Additional_Info":'AdditionalInfo','Date_of_Journey':'DateofJourney'},inplace=True)
df1
# Out:
#                 Airline DateofJourney    Source Destination            Route  \
# 0           Jet Airways     6/06/2019     Delhi      Cochin  DEL ? BOM ? COK
# 1                IndiGo    12/05/2019   Kolkata    Banglore  CCU ? MAA ? BLR
# 2           Jet Airways    21/05/2019     Delhi      Cochin  DEL ? BOM ? COK
# 3     Multiple carriers    21/05/2019     Delhi      Cochin  DEL ? BOM ? COK
# 4              Air Asia    24/06/2019  Banglore       Delhi        BLR ? DEL
# ...                 ...           ...       ...         ...              ...
# 2666          Air India     6/06/2019   Kolkata    Banglore  CCU ? DEL ? BLR
# 2667             IndiGo    27/03/2019   Kolkata    Banglore        CCU ? BLR
# 2668        Jet Airways     6/03/2019     Delhi      Cochin  DEL ? BOM ? COK
# 2669          Air India     6/03/2019     Delhi      Cochin  DEL ? BOM ? COK
# 2670  Multiple carriers    15/06/2019     Delhi      Cochin  DEL ? BOM ? COK
#
# ...

# %%
df1
# Out:
#                 Airline DateofJourney    Source Destination            Route  \
# 0           Jet Airways     6/06/2019     Delhi      Cochin  DEL ? BOM ? COK
# 1                IndiGo    12/05/2019   Kolkata    Banglore  CCU ? MAA ? BLR
# 2           Jet Airways    21/05/2019     Delhi      Cochin  DEL ? BOM ? COK
# 3     Multiple carriers    21/05/2019     Delhi      Cochin  DEL ? BOM ? COK
# 4              Air Asia    24/06/2019  Banglore       Delhi        BLR ? DEL
# ...                 ...           ...       ...         ...              ...
# 2666          Air India     6/06/2019   Kolkata    Banglore  CCU ? DEL ? BLR
# 2667             IndiGo    27/03/2019   Kolkata    Banglore        CCU ? BLR
# 2668        Jet Airways     6/03/2019     Delhi      Cochin  DEL ? BOM ? COK
# 2669          Air India     6/03/2019     Delhi      Cochin  DEL ? BOM ? COK
# 2670  Multiple carriers    15/06/2019     Delhi      Cochin  DEL ? BOM ? COK
#
# ...

# %%
df
# Out:
#            Airline DateofJourney    Source Destination                  Route  \
# 0           IndiGo    24/03/2019  Banglore   New Delhi              BLR ? DEL
# 1        Air India     1/05/2019   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2      Jet Airways     9/06/2019     Delhi      Cochin  DEL ? LKO ? BOM ? COK
# 3           IndiGo    12/05/2019   Kolkata    Banglore        CCU ? NAG ? BLR
# 4           IndiGo    01/03/2019  Banglore   New Delhi        BLR ? NAG ? DEL
# ...            ...           ...       ...         ...                    ...
# 10678     Air Asia     9/04/2019   Kolkata    Banglore              CCU ? BLR
# 10679    Air India    27/04/2019   Kolkata    Banglore              CCU ? BLR
# 10680  Jet Airways    27/04/2019  Banglore       Delhi              BLR ? DEL
# 10681      Vistara    01/03/2019  Banglore   New Delhi              BLR ? DEL
# 10682    Air India     9/05/2019     Delhi      Cochin  DEL ? GOI ? BOM ? COK
#
# ...

# %%
df1
# Out:
#                 Airline DateofJourney    Source Destination            Route  \
# 0           Jet Airways     6/06/2019     Delhi      Cochin  DEL ? BOM ? COK
# 1                IndiGo    12/05/2019   Kolkata    Banglore  CCU ? MAA ? BLR
# 2           Jet Airways    21/05/2019     Delhi      Cochin  DEL ? BOM ? COK
# 3     Multiple carriers    21/05/2019     Delhi      Cochin  DEL ? BOM ? COK
# 4              Air Asia    24/06/2019  Banglore       Delhi        BLR ? DEL
# ...                 ...           ...       ...         ...              ...
# 2666          Air India     6/06/2019   Kolkata    Banglore  CCU ? DEL ? BLR
# 2667             IndiGo    27/03/2019   Kolkata    Banglore        CCU ? BLR
# 2668        Jet Airways     6/03/2019     Delhi      Cochin  DEL ? BOM ? COK
# 2669          Air India     6/03/2019     Delhi      Cochin  DEL ? BOM ? COK
# 2670  Multiple carriers    15/06/2019     Delhi      Cochin  DEL ? BOM ? COK
#
# ...

# %%
df.dtypes
# Out:
# Airline           object
# DateofJourney     object
# Source            object
# Destination       object
# Route             object
# DepTime           object
# ArrivalTime       object
# Duration          object
# Totalstops        object
# AdditionalInfo    object
# Price              int64
# dtype: object

# %%
df.head(1)
# Out:
#   Airline DateofJourney    Source Destination DepTime   ArrivalTime Duration  \
# 0  IndiGo    24/03/2019  Banglore   New Delhi   22:20  01:10 22 Mar   2h 50m
#
#   Totalstops AdditionalInfo  Price
# 0   non-stop        No info   3897

# %%
df.isnull().sum()
# Out:
# Airline           0
# DateofJourney     0
# Source            0
# Destination       0
# DepTime           0
# ArrivalTime       0
# Duration          0
# Totalstops        1
# AdditionalInfo    0
# Price             0
# dtype: int64

# %%
# Replacing the Stop column by Integer 

df['Totalstops'] = df['Totalstops'].str.replace('non-stop','0')

# %%
df.sample(1)
# Out:
#           Airline DateofJourney Source Destination DepTime ArrivalTime  \
# 5507  Jet Airways    21/03/2019  Delhi      Cochin   13:00       18:50
#
#      Duration Totalstops AdditionalInfo  Price
# 5507   5h 50m          1        No info  12347

# %%
df['Totalstops'] = df['Totalstops'].str.replace('1 stop','1')

# %%
df['Totalstops'] = df['Totalstops'].str.replace('3 stops','3')

# %%
df.Totalstops.value_counts()
# Out:
# Totalstops
# 1          5625
# 0          3491
# 2 stops    1520
# 3 stops      45
# 4 stops       1
# Name: count, dtype: int64

# %%
df['Totalstops'] = df['Totalstops'].str.replace('4 stops','4')
